# %% [markdown]
# # AIRPLANE ANALYSIS

# %% [markdown]
# * In this notebook, i will get deeper into Airplane Analysis

# %% [markdown]
# #### import the neccessary modules

# %%
# import libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import csv

# %% [markdown]
# #### Load Airplane Data

# %%
with open('data/Airplane_data.csv', mode='r', encoding='utf-8') as file:
    data = pd.read_csv(file)

data.head()
# Out:
#          Event.Id Investigation.Type  Event.Date          Location  \
# 0  20080107X00026           Accident  2008-01-01        Sonoma, CA
# 1  20080109X00036           Accident  2008-01-01        Arcola, TX
# 2  20080115X00051           Accident  2008-01-02      Loveland, CO
# 3  20080210X00166           Accident  2008-01-02     Brunswick, GA
# 4  20080115X00046           Accident  2008-01-03  Stevensville, MD
#
#          Country Injury.Severity Aircraft.damage Aircraft.Category  \
# 0  United States       Non-Fatal     Substantial          Airplane
# 1  United States       Non-Fatal     Substantial          Airplane
# 2  United States       Non-Fatal     Substantial          Airplane
# 3  United States       Non-Fatal     Substantial          Airplane
# 4  United States       Non-Fatal     Substantial          Airplane
#
#                        Make         Model  ... Purpose.of.flight  \
# 0           BARNARD/STANCIL       GLASTAR  ...          Personal
# ...

# %% [markdown]
# ### Calculate the total number of accidents for each Airplane model to help calculate the accident rate

# %%
# Calculate the total number of accidents for each aircraft model
accidents_per_model = data.groupby('Model')['Event.Id'].count()

# Calculate the total number of accidents across all models
total_accidents = accidents_per_model.sum()

# Calculate the accident rate per aircraft model
accident_rate_per_model = accidents_per_model / total_accidents

# Display the accident rate per aircraft model
print(accident_rate_per_model.sort())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10252\2274813779.py in ?()
#       7 # Calculate the accident rate per aircraft model
#       8 accident_rate_per_model = accidents_per_model / total_accidents
#       9
#      10 # Display the accident rate per aircraft model
# ---> 11 print(accident_rate_per_model.sort())
#
# ~\anaconda3\envs\learn-env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort'
